# %%
import numpy as np 
import rioxarray as rxr
import os 
import matplotlib.pyplot as plt
import requests

# path to locally stored testdata
PATH = os.path.expanduser("~/Documents/Skyseed/data/multispectral_testarea_2d_50m/map/")

# import full rgb result
rgb = rxr.open_rasterio(os.path.join(PATH, "result.tif"))
rgb
# Out:
# <xarray.DataArray (band: 4, y: 2984, x: 3755)>
# [44819680 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 1 2 3 4
#   * y            (y) float64 52.39 52.39 52.39 52.39 ... 52.39 52.39 52.39 52.39
#   * x            (x) float64 14.29 14.29 14.29 14.29 ... 14.29 14.29 14.29 14.29
#     spatial_ref  int64 0
# Attributes:
#     _FillValue:    0.0
#     scale_factor:  1.0
#     add_offset:    0.0
#     grid_mapping:  spatial_ref

# %%
# import exemplary near infrared band
nir = rxr.open_rasterio(os.path.join(PATH, "result_NIR.tif"))
nir
# Out:
# <xarray.DataArray (band: 1, y: 2984, x: 3755)>
# [11204920 values with dtype=float32]
# Coordinates:
#   * band         (band) int64 1
#   * y            (y) float64 52.39 52.39 52.39 52.39 ... 52.39 52.39 52.39 52.39
#   * x            (x) float64 14.29 14.29 14.29 14.29 ... 14.29 14.29 14.29 14.29
#     spatial_ref  int64 0
# Attributes:
#     _FillValue:    nan
#     scale_factor:  1.0
#     add_offset:    0.0
#     grid_mapping:  spatial_ref

# %%
# print the CRS used and spatial extent
print("The CRS for this data is:", rgb.rio.crs)
print("The spatial extent is:", rgb.rio.bounds())
# Out:
# The CRS for this data is: EPSG:4326
# The spatial extent is: (14.293207930901957, 52.38986709588119, 14.29458681582204, 52.390537498322836)

# %%
# Try to import data from INSPIRE Download Service 
PATH_XML = os.path.expanduser("~/Documents/Skyseed/data/inspire_test.xml")

xml_str = open(PATH_XML).read()
# Out:
# 18920
